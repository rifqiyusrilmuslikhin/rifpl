# %% [markdown]
# # FPL Model — Colab smoke test
# Run from the cloned repository root. This notebook only installs and verifies the package.

# %%
# %pip install -e ".[dev]"

# %%
# !python -m pytest tests/test_smoke.py -q
import fpl_model

print(f"fpl_model {fpl_model.__version__} imported successfully")
